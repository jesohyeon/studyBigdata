# %% [markdown]
# ### 히스토그램

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 히스토그램 평균습도의 범위
mydata=pd.read_csv('C:\studyBigdata\studyBigdata\day05\data\mydata.csv')
mydata[['HM_AVG']].hist()
# Out:
# array([[<AxesSubplot:title={'center':'HM_AVG'}>]], dtype=object)

# %%
plt.hist(mydata['HM_AVG'], bins=10)
plt.title('평균습도')
plt.grid(True)
plt.show()
# Out:
# c:\Users\admin\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\admin\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44512 (\N{HANGUL SYLLABLE GYUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\admin\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49845 (\N{HANGUL SYLLABLE SEUB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\admin\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(10,5))
sns.distplot(mydata.HM_AVG, bins=10, kde=True)
# Out:
# c:\Users\admin\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='HM_AVG', ylabel='Density'>

# %%
df = pd.DataFrame(mydata)
df.describe()
# Out:
#                  TM      CA_TOT      HM_AVG      RN_DAY
# count  3.650000e+02  365.000000  365.000000  365.000000
# mean   2.015067e+07    5.098356   59.019178   -3.671507
# std    3.454755e+02    3.066515   14.973743    8.922004
# min    2.015010e+07    0.000000   28.900000   -9.000000
# 25%    2.015040e+07    2.600000   48.000000   -9.000000
# 50%    2.015070e+07    5.000000   59.400000   -9.000000
# 75%    2.015100e+07    7.800000   70.000000    0.500000
# max    2.015123e+07   10.000000   96.500000   45.500000

# %%
import scipy as sp

sp.stats.describe(mydata)
# Out:
# DescribeResult(nobs=365, minmax=(array([ 2.0150101e+07,  0.0000000e+00,  2.8900000e+01, -9.0000000e+00]), array([2.0151231e+07, 1.0000000e+01, 9.6500000e+01, 4.5500000e+01])), mean=array([ 2.01506683e+07,  5.09835616e+00,  5.90191781e+01, -3.67150685e+00]), variance=array([1.19353296e+05, 9.40351377e+00, 2.24212983e+02, 7.96021529e+01]), skewness=array([-0.01069441, -0.04127374,  0.08465603,  2.34500701]), kurtosis=array([-1.20571404, -1.16737904, -0.60915828,  7.10336469]))

# %% [markdown]
# # 박스플롯 => 4분위 값을 볼때 많이 사용

# %%
mydata.boxplot(column='RN_DAY')
# Out:
# <AxesSubplot:>

# %%
mydata.boxplot(column=['CA_TOT', 'HM_AVG', 'RN_DAY'])
# Out:
# <AxesSubplot:>

# %%
fid,    ax = plt.subplots()
ax.boxplot(mydata[['CA_TOT', 'HM_AVG', 'RN_DAY']])

plt.grid(True)
plt.show()

# %%
mydata_corr = mydata.iloc[:, 0:4]
mydata_corr.corr(method='pearson')
# Out:
#               TM    CA_TOT    HM_AVG    RN_DAY
# TM      1.000000  0.125144  0.272362  0.049048
# CA_TOT  0.125144  1.000000  0.665570  0.561871
# HM_AVG  0.272362  0.665570  1.000000  0.591783
# RN_DAY  0.049048  0.561871  0.591783  1.000000

# %%
plt.figure(figsize=(15,6))
plt.scatter(x=mydata_corr.HM_AVG, y=mydata_corr.CA_TOT, color='r', marker='x')
plt.xlabel('HM_AVG')
plt.ylabel('CA_TOT')
plt.show()

# %%
plt.figure(figsize=(15,6))
x=mydata.HM_AVG.to_numpy()
y=mydata.CA_TOT.to_numpy()
plt.plot(x,y,color='r', marker='o')

m.b=np.ployfit(x,y,1)
plt.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\studyBigdata\studyBigdata\day05\날씨바루_데이터분석.ipynb 셀 14 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/c%3A/studyBigdata/studyBigdata/day05/%EB%82%A0%EC%94%A8%EB%B0%94%EB%A3%A8_%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D.ipynb#X33sZmlsZQ%3D%3D?line=2'>3</a> y=mydata.CA_TOT.to_numpy()
#       <a href='vscode-notebook-cell:/c%3A/studyBigdata/studyBigdata/day05/%EB%82%A0%EC%94%A8%EB%B0%94%EB%A3%A8_%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D.ipynb#X33sZmlsZQ%3D%3D?line=3'>4</a> plt.plot(x,y,color='r', marker='o')
# ----> <a href='vscode-notebook-cell:/c%3A/studyBigdata/studyBigdata/day05/%EB%82%A0%EC%94%A8%EB%B0%94%EB%A3%A8_%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D.ipynb#X33sZmlsZQ%3D%3D?line=5'>6</a> m.b=np.ployfit(x,y,1)
# ...

# %%
plt.scatter(mydata['RN_DAY'], 
mydata['CA_TOT'],color='b', marker='o')
plt.xlabel('RN_DAY')
plt.ylabel('CA_TOT')
# Out:
# Text(0, 0.5, 'CA_TOT')

# %% [markdown]
# ##### 간단한 차트보기

# %%
mydata.RN_DAY.plot.line()
# Out:
# <AxesSubplot:>

# %%
mydata.RN_DAY.plot.bar()
# Out:
# <AxesSubplot:>

# %%
dr=pd.read_csv()
